# %%
from datetime import datetime
from lunarcalendar import Converter, Solar, Lunar, DateNotExist
import pandas as pd
from pprint import pprint
from tabulate import tabulate

# %%
#Writing using object oriented programming approach 
#class 1: convert_date
class convert_date:
    def __init__(self, year_start, year_end, month, day, name):
        self.year_start = year_start
        self.year_end = year_end
        self.month = month
        self.day = day
        self.name = name
        self.birthdates = []
        self.valid_list = []
        self.valid_list_with_repeats = []

    
    #check if the input date falls on a leap month (chinese lunar calendar thing), returns list of tuples (year,True/False)
    def is_valid_lunar_date(self):
        for year in range(self.year_start, self.year_end+1): #can handle years 1900 to 2100 for range we do +1
            try:   
                lunar = Lunar(year, self.month, self.day, isleap=True)
                #print(f'You will have two birthdays in the year {year}! One on the initial month (month {self.month}) and one on the leap month (2nd month {self.month})')
                self.valid_list.append((year, True))
            except DateNotExist:
                self.valid_list.append((year, False))

        #pprint(self.valid_list)
        return self.valid_list
    

    #create a list of birthdays over the range of years, one birthday for nonleap months and two for leap months
    def create_birthday_list(self):
        for index in convert_date.is_valid_lunar_date(self):
            #conditional will print two birthdays if valid is true, one for initial month and one for leap month 
            if index[1] == True:
                #set lunar date and isleap parameter with opposite boolean (True->False) for initial birthday
                lunar2 = Lunar(index[0], self.month, self.day, isleap=not index[1])
                #print(lunar2)

                solar = str(Converter.Lunar2Solar(lunar2))
                #print(f'{solar} initial birthday')
                #print(lunar2.to_date(), type(lunar2.to_date())) #convert to datetime.date format
                self.birthdates.append(str(lunar2.to_date()))
                self.valid_list_with_repeats.append(True)
                

                #set lunar date and isleap parameter with original boolean (True) for leap month birthdate
                lunar = Lunar(index[0], self.month, self.day, isleap=index[1])
                #print(lunar)

                solar = str(Converter.Lunar2Solar(lunar))
                #print(f'{solar} leap month birthday')
                #print(lunar.to_date(), type(lunar.to_date())) #convert to datetime.date format
                self.birthdates.append(str(lunar.to_date()))
                self.valid_list_with_repeats.append(True)
            else:
                #when the date does not land on a leap month (valid==false)
                lunar = Lunar(index[0], self.month, self.day, isleap=index[1])
                #print(lunar)

                solar = str(Converter.Lunar2Solar(lunar))
                #print(solar)
                #print(lunar.to_date()) #convert to datetime.date format
                self.birthdates.append(str(lunar.to_date()))
                self.valid_list_with_repeats.append(False)
        
        #pprint(self.birthdates)
        birthdate_len = len(self.birthdates)
        return self.birthdates, birthdate_len

# %%
jason_bday = convert_date(2000, 2100, 8, 3, 'Jason')

print(jason_bday.is_valid_lunar_date())
# Out:
# [(2000, False), (2001, False), (2002, False), (2003, False), (2004, False), (2005, False), (2006, False), (2007, False), (2008, False), (2009, False), (2010, False), (2011, False), (2012, False), (2013, False), (2014, False), (2015, False), (2016, False), (2017, False), (2018, False), (2019, False), (2020, False), (2021, False), (2022, False), (2023, False), (2024, False), (2025, False), (2026, False), (2027, False), (2028, False), (2029, False), (2030, False), (2031, False), (2032, False), (2033, False), (2034, False), (2035, False), (2036, False), (2037, False), (2038, False), (2039, False), (2040, False), (2041, False), (2042, False), (2043, False), (2044, False), (2045, False), (2046, False), (2047, False), (2048, False), (2049, False), (2050, False), (2051, False), (2052, True), (2053, False), (2054, False), (2055, False), (2056, False), (2057, False), (2058, False), (2059, False), (2060, False), (2061, False), (2062, False), (2063, False), (2064, False), (2065, False), (2066, False), (2067, False), (2068, False), (2069, False), (2070, False), (2071, True), (2072, False), (2073, False), (2074, False), (2075, False), (2076, False), (2077, False), (2078, False), (2079, False), (2080, False), (2081, False), (2082, False), (2083, False), (2084, False), (2085, False), (2086, False), (2087, False), (2088, False), (2089, False), (2090, True), (2091, False), (2092, False), (2093, False), (2094, False), (2095, False), (2096, False), (2097, False), (2098, False), (2099, False), (2100, False)]

# %%
print(jason_bday.create_birthday_list())
# Out:
# (['2000-08-31', '2001-09-19', '2002-09-09', '2003-08-30', '2004-09-16', '2005-09-06', '2006-09-24', '2007-09-13', '2008-09-02', '2009-09-21', '2010-09-10', '2011-08-31', '2012-09-18', '2013-09-07', '2014-08-27', '2015-09-15', '2016-09-03', '2017-09-22', '2018-09-12', '2019-09-01', '2020-09-19', '2021-09-09', '2022-08-29', '2023-09-17', '2024-09-05', '2025-09-24', '2026-09-13', '2027-09-03', '2028-09-21', '2029-09-10', '2030-08-31', '2031-09-19', '2032-09-07', '2033-08-27', '2034-09-15', '2035-09-04', '2036-09-22', '2037-09-12', '2038-09-01', '2039-09-20', '2040-09-08', '2041-08-29', '2042-09-16', '2043-09-05', '2044-09-23', '2045-09-13', '2046-09-03', '2047-09-22', '2048-09-10', '2049-08-30', '2050-09-18', '2051-09-07', '2052-08-26', '2052-09-25', '2053-09-14', '2054-09-04', '2055-09-23', '2056-09-12', '2057-09-01', '2058-09-20', '2059-09-09', '2060-08-28', '2061-09-16', '2062-09-05', '2063-09-24', '2064-09-13', '2065-09-03', '2066-09-21', '2067-09-11', '2068-08-30', '2069-09-17', '2070-09-07', '2071-08-27', '2071-09-26', '2072-09-14', '2073-09-04', '2074-09-23', '2075-09-12', '2076-08-31', '2077-09-19', '2078-09-08', '2079-08-29', '2080-09-16', '2081-09-05', '2082-09-24', '2083-09-14', '2084-09-02', '2085-09-21', '2086-09-10', '2087-08-30', '2088-09-17', '2089-09-07', '2090-08-27', '2090-09-26', '2091-09-15', '2092-09-04', '2093-09-23', '2094-09-12', '2095-09-01', '2096-09-18', '2097-09-08', '2098-08-28', '2099-09-17', '2100-09-06', '2000-08-31', '2001-09-19', '2002-09-09', '2003-08-30', '2004-09-16', '2005-09-06', '2006-09-24', '2007-09-13', '2008-09-02', '2009-09-21', '2010-09-10', '2011-08-31', '2012-09-18', '2013-09-07', '2014-08-27', '2015-09-15', '2016-09-03', '2017-09-22', '2018-09-12', '2019-09-01', '2020-09-19', '2021-09-09', '2022-08-29', '2023-09-17', '2024-09-05', '2025-09-24', '2026-09-13', '2027-09-03', '2028-09-21', '2029-09-10', '2030-08-31', '2031-09-19', '2032-09-07', '2033-08-27', '2034-09-15', '2035-09-04', '2036-09-22', '2037-09-12', '2038-09-01', '2039-09-20', '2040-09-08', '2041-08-29', '2042-09-16', '2043-09-05', '2044-09-23', '2045-09-13', '2046-09-03', '2047-09-22', '2048-09-10', '2049-08-30', '2050-09-18', '2051-09-07', '2052-08-26', '2052-09-25', '2053-09-14', '2054-09-04', '2055-09-23', '2056-09-12', '2057-09-01', '2058-09-20', '2059-09-09', '2060-08-28', '2061-09-16', '2062-09-05', '2063-09-24', '2064-09-13', '2065-09-03', '2066-09-21', '2067-09-11', '2068-08-30', '2069-09-17', '2070-09-07', '2071-08-27', '2071-09-26', '2072-09-14', '2073-09-04', '2074-09-23', '2075-09-12', '2076-08-31', '2077-09-19', '2078-09-08', '2079-08-29', '2080-09-16', '2081-09-05', '2082-09-24', '2083-09-14', '2084-09-02', '2085-09-21', '2086-09-10', '2087-08-30', '2088-09-17', '2089-09-07', '2090-08-27', '2090-09-26', '2091-09-15', '2092-09-04', '2093-09-23', '2094-09-12', '2095-09-01', '2096-09-18', '2097-09-08', '2098-08-28', '2099-09-17', '2100-09-06'], 208)

# %%
#class 2: to_dataframe
class to_dataframe(convert_date):

    #creating empty dataframe with headers   
    def empty_dataframe(self): 
        column_names = ['Subject','Start Date', 'Start Time','Description']
        df = pd.DataFrame(columns = column_names)
        return df
    
    #appending all columns to our dataframe (except description)
    def append_subject_startdate_starttime(self):
        df = to_dataframe.empty_dataframe(self)
        birthdate_list, birthdate_list_len = self.create_birthday_list()

        df['Subject'] = [f'{self.name}s birthday' for subject in range(birthdate_list_len)]

        # Use pandas.to_datetime() to convert string to datetime format (only keeping date portion)
        df["Start Date"] = birthdate_list
        df["Start Date"] = pd.to_datetime(df["Start Date"]).dt.date 

        df['Start Time'] = ['9:00:00' for starttime in range(birthdate_list_len)]
        return df
        
    #short function that attaches the appropriate suffix based on the number   
    def suffix(self, d): 
        return 'th' if 11<=d<=13 else {1:'st',2:'nd',3:'rd'}.get(d%10, 'th')
        

    #display different description message based on whether or not the birthday lands on a leap month    
    def append_description(self):
        df = to_dataframe.append_subject_startdate_starttime(self)

        #messages for regular birthdays and leap month birthdays
        birthdate_year = pd.to_datetime(df["Start Date"]).dt.year #df[Start Date] that only contains the year portion

        desc_list = []
        for index in range(len(self.valid_list_with_repeats)):
            if self.valid_list_with_repeats[index]==False:
                desc_list.append(f'Its {self.name}s birthday today in the chinese lunar calendar ({birthdate_year.iloc[index]}, {self.month}{self.suffix(self.month)} month, {self.day}{self.suffix(self.day)} day)!')
            else:
                desc_list.append(f'Its {self.name}s birthday today in the chinese lunar calendar ({birthdate_year.iloc[index]}, {self.month}{self.suffix(self.month)} month, {self.day}{self.suffix(self.day)} day)! This is one of two birthdays {self.name} will have this year since their birthday lands on a leap month.')  
        
        df['Description'] = desc_list
        return df
        
    
    def display_and_save_to_csv(self):
        df = to_dataframe.append_description(self)
        column_names = ['Subject','Start Date', 'Start Time','Description']

        #sample table
        #print(tabulate(df, headers=column_names, tablefmt='psql'))

        #save as csv
        df.to_csv('lunar_to_gregorian_birthdays.csv', index = False)

        return tabulate(df, headers=column_names, tablefmt='psql')

# %%
jason_bday = to_dataframe(2000, 2100, 8, 3, 'Jason')

jason_bday.empty_dataframe()
# Out:
# Empty DataFrame
# Columns: [Subject, Start Date, Start Time, Description]
# Index: []

# %%
print(jason_bday.display_and_save_to_csv())
# Out:
# +-----+-----------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |     | Subject         | Start Date   | Start Time   | Description                                                                                                                                                                            |
# |-----+-----------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |   0 | Jasons birthday | 2000-08-31   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2000, 8th month, 3rd day)!                                                                                                    |
# |   1 | Jasons birthday | 2001-09-19   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2001, 8th month, 3rd day)!                                                                                                    |
# |   2 | Jasons birthday | 2002-09-09   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2002, 8th month, 3rd day)!                                                                                                    |
# |   3 | Jasons birthday | 2003-08-30   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2003, 8th month, 3rd day)!                                                                                                    |
# |   4 | Jasons birthday | 2004-09-16   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2004, 8th month, 3rd day)!                                                                                                    |
# |   5 | Jasons birthday | 2005-09-06   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2005, 8th month, 3rd day)!                                                                                                    |
# |   6 | Jasons birthday | 2006-09-24   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2006, 8th month, 3rd day)!                                                                                                    |
# |   7 | Jasons birthday | 2007-09-13   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2007, 8th month, 3rd day)!                                                                                                    |
# |   8 | Jasons birthday | 2008-09-02   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2008, 8th month, 3rd day)!                                                                                                    |
# |   9 | Jasons birthday | 2009-09-21   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2009, 8th month, 3rd day)!                                                                                                    |
# |  10 | Jasons birthday | 2010-09-10   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2010, 8th month, 3rd day)!                                                                                                    |
# |  11 | Jasons birthday | 2011-08-31   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2011, 8th month, 3rd day)!                                                                                                    |
# |  12 | Jasons birthday | 2012-09-18   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2012, 8th month, 3rd day)!                                                                                                    |
# |  13 | Jasons birthday | 2013-09-07   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2013, 8th month, 3rd day)!                                                                                                    |
# |  14 | Jasons birthday | 2014-08-27   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2014, 8th month, 3rd day)!                                                                                                    |
# |  15 | Jasons birthday | 2015-09-15   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2015, 8th month, 3rd day)!                                                                                                    |
# |  16 | Jasons birthday | 2016-09-03   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2016, 8th month, 3rd day)!                                                                                                    |
# |  17 | Jasons birthday | 2017-09-22   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2017, 8th month, 3rd day)!                                                                                                    |
# |  18 | Jasons birthday | 2018-09-12   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2018, 8th month, 3rd day)!                                                                                                    |
# |  19 | Jasons birthday | 2019-09-01   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2019, 8th month, 3rd day)!                                                                                                    |
# |  20 | Jasons birthday | 2020-09-19   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2020, 8th month, 3rd day)!                                                                                                    |
# |  21 | Jasons birthday | 2021-09-09   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2021, 8th month, 3rd day)!                                                                                                    |
# |  22 | Jasons birthday | 2022-08-29   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2022, 8th month, 3rd day)!                                                                                                    |
# |  23 | Jasons birthday | 2023-09-17   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2023, 8th month, 3rd day)!                                                                                                    |
# |  24 | Jasons birthday | 2024-09-05   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2024, 8th month, 3rd day)!                                                                                                    |
# |  25 | Jasons birthday | 2025-09-24   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2025, 8th month, 3rd day)!                                                                                                    |
# |  26 | Jasons birthday | 2026-09-13   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2026, 8th month, 3rd day)!                                                                                                    |
# |  27 | Jasons birthday | 2027-09-03   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2027, 8th month, 3rd day)!                                                                                                    |
# |  28 | Jasons birthday | 2028-09-21   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2028, 8th month, 3rd day)!                                                                                                    |
# |  29 | Jasons birthday | 2029-09-10   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2029, 8th month, 3rd day)!                                                                                                    |
# |  30 | Jasons birthday | 2030-08-31   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2030, 8th month, 3rd day)!                                                                                                    |
# |  31 | Jasons birthday | 2031-09-19   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2031, 8th month, 3rd day)!                                                                                                    |
# |  32 | Jasons birthday | 2032-09-07   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2032, 8th month, 3rd day)!                                                                                                    |
# |  33 | Jasons birthday | 2033-08-27   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2033, 8th month, 3rd day)!                                                                                                    |
# |  34 | Jasons birthday | 2034-09-15   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2034, 8th month, 3rd day)!                                                                                                    |
# |  35 | Jasons birthday | 2035-09-04   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2035, 8th month, 3rd day)!                                                                                                    |
# |  36 | Jasons birthday | 2036-09-22   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2036, 8th month, 3rd day)!                                                                                                    |
# |  37 | Jasons birthday | 2037-09-12   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2037, 8th month, 3rd day)!                                                                                                    |
# |  38 | Jasons birthday | 2038-09-01   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2038, 8th month, 3rd day)!                                                                                                    |
# |  39 | Jasons birthday | 2039-09-20   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2039, 8th month, 3rd day)!                                                                                                    |
# |  40 | Jasons birthday | 2040-09-08   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2040, 8th month, 3rd day)!                                                                                                    |
# |  41 | Jasons birthday | 2041-08-29   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2041, 8th month, 3rd day)!                                                                                                    |
# |  42 | Jasons birthday | 2042-09-16   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2042, 8th month, 3rd day)!                                                                                                    |
# |  43 | Jasons birthday | 2043-09-05   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2043, 8th month, 3rd day)!                                                                                                    |
# |  44 | Jasons birthday | 2044-09-23   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2044, 8th month, 3rd day)!                                                                                                    |
# |  45 | Jasons birthday | 2045-09-13   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2045, 8th month, 3rd day)!                                                                                                    |
# |  46 | Jasons birthday | 2046-09-03   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2046, 8th month, 3rd day)!                                                                                                    |
# |  47 | Jasons birthday | 2047-09-22   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2047, 8th month, 3rd day)!                                                                                                    |
# |  48 | Jasons birthday | 2048-09-10   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2048, 8th month, 3rd day)!                                                                                                    |
# |  49 | Jasons birthday | 2049-08-30   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2049, 8th month, 3rd day)!                                                                                                    |
# |  50 | Jasons birthday | 2050-09-18   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2050, 8th month, 3rd day)!                                                                                                    |
# |  51 | Jasons birthday | 2051-09-07   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2051, 8th month, 3rd day)!                                                                                                    |
# |  52 | Jasons birthday | 2052-08-26   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2052, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  53 | Jasons birthday | 2052-09-25   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2052, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  54 | Jasons birthday | 2053-09-14   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2053, 8th month, 3rd day)!                                                                                                    |
# |  55 | Jasons birthday | 2054-09-04   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2054, 8th month, 3rd day)!                                                                                                    |
# |  56 | Jasons birthday | 2055-09-23   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2055, 8th month, 3rd day)!                                                                                                    |
# |  57 | Jasons birthday | 2056-09-12   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2056, 8th month, 3rd day)!                                                                                                    |
# |  58 | Jasons birthday | 2057-09-01   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2057, 8th month, 3rd day)!                                                                                                    |
# |  59 | Jasons birthday | 2058-09-20   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2058, 8th month, 3rd day)!                                                                                                    |
# |  60 | Jasons birthday | 2059-09-09   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2059, 8th month, 3rd day)!                                                                                                    |
# |  61 | Jasons birthday | 2060-08-28   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2060, 8th month, 3rd day)!                                                                                                    |
# |  62 | Jasons birthday | 2061-09-16   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2061, 8th month, 3rd day)!                                                                                                    |
# |  63 | Jasons birthday | 2062-09-05   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2062, 8th month, 3rd day)!                                                                                                    |
# |  64 | Jasons birthday | 2063-09-24   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2063, 8th month, 3rd day)!                                                                                                    |
# |  65 | Jasons birthday | 2064-09-13   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2064, 8th month, 3rd day)!                                                                                                    |
# |  66 | Jasons birthday | 2065-09-03   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2065, 8th month, 3rd day)!                                                                                                    |
# |  67 | Jasons birthday | 2066-09-21   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2066, 8th month, 3rd day)!                                                                                                    |
# |  68 | Jasons birthday | 2067-09-11   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2067, 8th month, 3rd day)!                                                                                                    |
# |  69 | Jasons birthday | 2068-08-30   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2068, 8th month, 3rd day)!                                                                                                    |
# |  70 | Jasons birthday | 2069-09-17   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2069, 8th month, 3rd day)!                                                                                                    |
# |  71 | Jasons birthday | 2070-09-07   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2070, 8th month, 3rd day)!                                                                                                    |
# |  72 | Jasons birthday | 2071-08-27   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2071, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  73 | Jasons birthday | 2071-09-26   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2071, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  74 | Jasons birthday | 2072-09-14   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2072, 8th month, 3rd day)!                                                                                                    |
# |  75 | Jasons birthday | 2073-09-04   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2073, 8th month, 3rd day)!                                                                                                    |
# |  76 | Jasons birthday | 2074-09-23   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2074, 8th month, 3rd day)!                                                                                                    |
# |  77 | Jasons birthday | 2075-09-12   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2075, 8th month, 3rd day)!                                                                                                    |
# |  78 | Jasons birthday | 2076-08-31   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2076, 8th month, 3rd day)!                                                                                                    |
# |  79 | Jasons birthday | 2077-09-19   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2077, 8th month, 3rd day)!                                                                                                    |
# |  80 | Jasons birthday | 2078-09-08   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2078, 8th month, 3rd day)!                                                                                                    |
# |  81 | Jasons birthday | 2079-08-29   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2079, 8th month, 3rd day)!                                                                                                    |
# |  82 | Jasons birthday | 2080-09-16   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2080, 8th month, 3rd day)!                                                                                                    |
# |  83 | Jasons birthday | 2081-09-05   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2081, 8th month, 3rd day)!                                                                                                    |
# |  84 | Jasons birthday | 2082-09-24   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2082, 8th month, 3rd day)!                                                                                                    |
# |  85 | Jasons birthday | 2083-09-14   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2083, 8th month, 3rd day)!                                                                                                    |
# |  86 | Jasons birthday | 2084-09-02   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2084, 8th month, 3rd day)!                                                                                                    |
# |  87 | Jasons birthday | 2085-09-21   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2085, 8th month, 3rd day)!                                                                                                    |
# |  88 | Jasons birthday | 2086-09-10   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2086, 8th month, 3rd day)!                                                                                                    |
# |  89 | Jasons birthday | 2087-08-30   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2087, 8th month, 3rd day)!                                                                                                    |
# |  90 | Jasons birthday | 2088-09-17   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2088, 8th month, 3rd day)!                                                                                                    |
# |  91 | Jasons birthday | 2089-09-07   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2089, 8th month, 3rd day)!                                                                                                    |
# |  92 | Jasons birthday | 2090-08-27   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2090, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  93 | Jasons birthday | 2090-09-26   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2090, 8th month, 3rd day)! This is one of two birthdays Jason will have this year since their birthday lands on a leap month. |
# |  94 | Jasons birthday | 2091-09-15   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2091, 8th month, 3rd day)!                                                                                                    |
# |  95 | Jasons birthday | 2092-09-04   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2092, 8th month, 3rd day)!                                                                                                    |
# |  96 | Jasons birthday | 2093-09-23   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2093, 8th month, 3rd day)!                                                                                                    |
# |  97 | Jasons birthday | 2094-09-12   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2094, 8th month, 3rd day)!                                                                                                    |
# |  98 | Jasons birthday | 2095-09-01   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2095, 8th month, 3rd day)!                                                                                                    |
# |  99 | Jasons birthday | 2096-09-18   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2096, 8th month, 3rd day)!                                                                                                    |
# | 100 | Jasons birthday | 2097-09-08   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2097, 8th month, 3rd day)!                                                                                                    |
# | 101 | Jasons birthday | 2098-08-28   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2098, 8th month, 3rd day)!                                                                                                    |
# | 102 | Jasons birthday | 2099-09-17   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2099, 8th month, 3rd day)!                                                                                                    |
# | 103 | Jasons birthday | 2100-09-06   | 9:00:00      | Its Jasons birthday today in the chinese lunar calendar (2100, 8th month, 3rd day)!                                                                                                    |
# +-----+-----------------+--------------+--------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
pd.read_csv('lunar_to_gregorian_birthdays.csv')
# Out:
#              Subject  Start Date Start Time  \
# 0    Jasons birthday  2000-08-31    9:00:00
# 1    Jasons birthday  2001-09-19    9:00:00
# 2    Jasons birthday  2002-09-09    9:00:00
# 3    Jasons birthday  2003-08-30    9:00:00
# 4    Jasons birthday  2004-09-16    9:00:00
# ..               ...         ...        ...
# 99   Jasons birthday  2096-09-18    9:00:00
# 100  Jasons birthday  2097-09-08    9:00:00
# 101  Jasons birthday  2098-08-28    9:00:00
# 102  Jasons birthday  2099-09-17    9:00:00
# 103  Jasons birthday  2100-09-06    9:00:00
#
#                                            Description
# 0    Its Jasons birthday today in the chinese lunar...
# 1    Its Jasons birthday today in the chinese lunar...
# 2    Its Jasons birthday today in the chinese lunar...
# 3    Its Jasons birthday today in the chinese lunar...
# 4    Its Jasons birthday today in the chinese lunar...
# ..                                                 ...
# 99   Its Jasons birthday today in the chinese lunar...
# 100  Its Jasons birthday today in the chinese lunar...
# 101  Its Jasons birthday today in the chinese lunar...
# 102  Its Jasons birthday today in the chinese lunar...
# 103  Its Jasons birthday today in the chinese lunar...
#
# [104 rows x 4 columns]
